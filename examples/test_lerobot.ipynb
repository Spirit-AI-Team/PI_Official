# %%
import shutil
import os
from lerobot.common.datasets.lerobot_dataset import LEROBOT_HOME
from lerobot.common.datasets.lerobot_dataset import LeRobotDataset
# import tensorflow_datasets as tfds
import tyro
import h5py
import torch
import tqdm
import numpy as np
from multiprocessing.pool import ThreadPool

# %%
from lerobot.common.datasets.lerobot_dataset import LeRobotDataset
REPO_NAME = "20250214_Y_AL05_zhuyaoshibiao_GY_ai_biaozhu"
dataset = LeRobotDataset(repo_id=REPO_NAME, local_files_only=True)
# Out:
# Returning existing local_dir `/pfstem/likaiyu/resources/lerobot/20250214_Y_AL05_zhuyaoshibiao_GY_ai_biaozhu` as remote repo cannot be accessed in `snapshot_download` (None).
# Returning existing local_dir `/pfstem/likaiyu/resources/lerobot/20250214_Y_AL05_zhuyaoshibiao_GY_ai_biaozhu` as remote repo cannot be accessed in `snapshot_download` (None).
# Resolving data files:   0%|          | 0/35 [00:00<?, ?it/s]
# Loading dataset shards:   0%|          | 0/178 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 REPO_NAME = "20250214_Y_AL05_zhuyaoshibiao_GY_ai_biaozhu"
# ----> 2 dataset = LeRobotDataset(repo_id=REPO_NAME, local_files_only=True)
#
# File ~/PI_Official/.venv/lib/python3.11/site-packages/lerobot/common/datasets/lerobot_dataset.py:464, in LeRobotDataset.__init__(self, repo_id, root, episodes, image_transforms, delta_timestamps, tolerance_s, download_videos, local_files_only, video_backend)
#     461 self.episode_data_index = get_episode_data_index(self.meta.episodes, self.episodes)
#     463 # Check timestamps
# --> 464 check_timestamps_sync(self.hf_dataset, self.episode_data_index, self.fps, self.tolerance_s)
#     466 # Setup delta_indices
#     467 if self.delta_timestamps is not None:
#
# File ~/PI_Official/.venv/lib/python3.11/site-packages/lerobot/common/datasets/utils.py:440, in check_timestamps_sync(hf_dataset, episode_data_index, fps, tolerance_s, raise_value_error)
#     437         outside_tolerances.append(entry)
#     439     if raise_value_error:
# --> 440         raise ValueError(
#     441             f"""One or several timestamps unexpectedly violate the tolerance inside episode range.
#     442             This might be due to synchronization issues with timestamps during data collection.
#     443             \n{pformat(outside_tolerances)}"""
#     444         )
#     445     return False
#     447 return True
#
# ValueError: One or several timestamps unexpectedly violate the tolerance inside episode range.
#                 This might be due to synchronization issues with timestamps during data collection.
#
# [{'diff': tensor([-57.5000]),
#   'episode_index': 0,
#   'timestamps': [tensor([57.5000]), tensor([0.])]},
#  {'diff': tensor([-45.3000]),
#   'episode_index': 1,
#   'timestamps': [tensor([45.3000]), tensor([0.])]},
#  {'diff': tensor([-24.9000]),
#   'episode_index': 3,
#   'timestamps': [tensor([24.9000]), tensor([0.])]},
#  {'diff': tensor([-36.4000]),
#   'episode_index': 4,
#   'timestamps': [tensor([36.4000]), tensor([0.])]},
#  {'diff': tensor([-20.4000]),
#   'episode_index': 5,
#   'timestamps': [tensor([20.4000]), tensor([0.])]},
#  {'diff': tensor([-39.9000]),
#   'episode_index': 6,
#   'timestamps': [tensor([39.9000]), tensor([0.])]},
#  {'diff': tensor([-29.6000]),
#   'episode_index': 7,
#   'timestamps': [tensor([29.6000]), tensor([0.])]},
#  {'diff': tensor([-35.5000]),
#   'episode_index': 8,
#   'timestamps': [tensor([35.5000]), tensor([0.])]},
#  {'diff': tensor([-49.8000]),
#   'episode_index': 9,
#   'timestamps': [tensor([49.8000]), tensor([0.])]},
#  {'diff': tensor([-42.9000]),
#   'episode_index': 10,
#   'timestamps': [tensor([42.9000]), tensor([0.])]},
#  {'diff': tensor([-26.8000]),
#   'episode_index': 11,
#   'timestamps': [tensor([26.8000]), tensor([0.])]},
#  {'diff': tensor([-32.4000]),
#   'episode_index': 12,
#   'timestamps': [tensor([32.4000]), tensor([0.])]},
#  {'diff': tensor([-34.9000]),
#   'episode_index': 13,
#   'timestamps': [tensor([34.9000]), tensor([0.])]},
#  {'diff': tensor([-45.7000]),
#   'episode_index': 14,
#   'timestamps': [tensor([45.7000]), tensor([0.])]},
#  {'diff': tensor([-28.7000]),
#   'episode_index': 15,
#   'timestamps': [tensor([28.7000]), tensor([0.])]},
#  {'diff': tensor([-59.1000]),
#   'episode_index': 16,
#   'timestamps': [tensor([59.1000]), tensor([0.])]},
#  {'diff': tensor([-49.1000]),
#   'episode_index': 17,
#   'timestamps': [tensor([49.1000]), tensor([0.])]},
#  {'diff': tensor([-43.]),
#   'episode_index': 18,
#   'timestamps': [tensor([43.]), tensor([0.])]},
#  {'diff': tensor([-22.8000]),
#   'episode_index': 19,
#   'timestamps': [tensor([22.8000]), tensor([0.])]},
#  {'diff': tensor([-56.2000]),
#   'episode_index': 20,
#   'timestamps': [tensor([56.2000]), tensor([0.])]},
#  {'diff': tensor([-41.1000]),
#   'episode_index': 21,
#   'timestamps': [tensor([41.1000]), tensor([0.])]},
#  {'diff': tensor([-24.8000]),
#   'episode_index': 22,
#   'timestamps': [tensor([24.8000]), tensor([0.])]},
#  {'diff': tensor([-24.7000]),
#   'episode_index': 23,
#   'timestamps': [tensor([24.7000]), tensor([0.])]},
#  {'diff': tensor([-42.2000]),
#   'episode_index': 24,
#   'timestamps': [tensor([42.2000]), tensor([0.])]},
#  {'diff': tensor([-28.7000]),
#   'episode_index': 25,
#   'timestamps': [tensor([28.7000]), tensor([0.])]},
#  {'diff': tensor([-55.8000]),
#   'episode_index': 26,
#   'timestamps': [tensor([55.8000]), tensor([0.])]},
#  {'diff': tensor([-33.7000]),
#   'episode_index': 27,
#   'timestamps': [tensor([33.7000]), tensor([0.])]},
#  {'diff': tensor([-42.2000]),
#   'episode_index': 28,
#   'timestamps': [tensor([42.2000]), tensor([0.])]},
#  {'diff': tensor([-47.6000]),
#   'episode_index': 29,
#   'timestamps': [tensor([47.6000]), tensor([0.])]},
#  {'diff': tensor([-32.6000]),
#   'episode_index': 30,
#   'timestamps': [tensor([32.6000]), tensor([0.])]},
#  {'diff': tensor([-46.6000]),
#   'episode_index': 31,
#   'timestamps': [tensor([46.6000]), tensor([0.])]},
#  {'diff': tensor([-26.8000]),
#   'episode_index': 32,
#   'timestamps': [tensor([26.8000]), tensor([0.])]},
#  {'diff': tensor([-37.2000]),
#   'episode_index': 33,
#   'timestamps': [tensor([37.2000]), tensor([0.])]},
#  {'diff': tensor([-43.8000]),
#   'episode_index': 34,
#   'timestamps': [tensor([43.8000]), tensor([0.])]},
#  {'diff': tensor([-43.4000]),
#   'episode_index': 35,
#   'timestamps': [tensor([43.4000]), tensor([0.])]},
#  {'diff': tensor([-39.]),
#   'episode_index': 36,
#   'timestamps': [tensor([39.]), tensor([0.])]},
#  {'diff': tensor([-24.3000]),
#   'episode_index': 37,
#   'timestamps': [tensor([24.3000]), tensor([0.])]},
#  {'diff': tensor([-28.1000]),
#   'episode_index': 38,
#   'timestamps': [tensor([28.1000]), tensor([0.])]},
#  {'diff': tensor([-32.8000]),
#   'episode_index': 39,
#   'timestamps': [tensor([32.8000]), tensor([0.])]},
#  {'diff': tensor([-34.6000]),
#   'episode_index': 40,
#   'timestamps': [tensor([34.6000]), tensor([0.])]},
#  {'diff': tensor([-22.6000]),
#   'episode_index': 41,
#   'timestamps': [tensor([22.6000]), tensor([0.])]},
#  {'diff': tensor([-35.2000]),
#   'episode_index': 42,
#   'timestamps': [tensor([35.2000]), tensor([0.])]},
#  {'diff': tensor([-29.2000]),
#   'episode_index': 43,
#   'timestamps': [tensor([29.2000]), tensor([0.])]},
#  {'diff': tensor([-33.7000]),
#   'episode_index': 44,
#   'timestamps': [tensor([33.7000]), tensor([0.])]},
#  {'diff': tensor([-34.4000]),
#   'episode_index': 45,
#   'timestamps': [tensor([34.4000]), tensor([0.])]},
#  {'diff': tensor([-42.2000]),
#   'episode_index': 46,
#   'timestamps': [tensor([42.2000]), tensor([0.])]},
#  {'diff': tensor([-30.]),
#   'episode_index': 47,
#   'timestamps': [tensor([30.]), tensor([0.])]},
#  {'diff': tensor([-50.6000]),
#   'episode_index': 48,
#   'timestamps': [tensor([50.6000]), tensor([0.])]},
#  {'diff': tensor([-34.2000]),
#   'episode_index': 49,
#   'timestamps': [tensor([34.2000]), tensor([0.])]},
#  {'diff': tensor([-72.5000]),
#   'episode_index': 50,
#   'timestamps': [tensor([72.5000]), tensor([0.])]},
#  {'diff': tensor([-58.5000]),
#   'episode_index': 51,
#   'timestamps': [tensor([58.5000]), tensor([0.])]},
#  {'diff': tensor([-33.2000]),
#   'episode_index': 52,
#   'timestamps': [tensor([33.2000]), tensor([0.])]},
#  {'diff': tensor([-35.3000]),
#   'episode_index': 53,
#   'timestamps': [tensor([35.3000]), tensor([0.])]},
#  {'diff': tensor([-28.]),
#   'episode_index': 54,
#   'timestamps': [tensor([28.]), tensor([0.])]},
#  {'diff': tensor([-30.3000]),
#   'episode_index': 55,
#   'timestamps': [tensor([30.3000]), tensor([0.])]},
#  {'diff': tensor([-46.]),
#   'episode_index': 56,
#   'timestamps': [tensor([46.]), tensor([0.])]},
#  {'diff': tensor([-31.2000]),
#   'episode_index': 57,
#   'timestamps': [tensor([31.2000]), tensor([0.])]},
#  {'diff': tensor([-25.3000]),
#   'episode_index': 58,
#   'timestamps': [tensor([25.3000]), tensor([0.])]},
#  {'diff': tensor([-32.7000]),
#   'episode_index': 59,
#   'timestamps': [tensor([32.7000]), tensor([0.])]},
#  {'diff': tensor([-26.2000]),
#   'episode_index': 60,
#   'timestamps': [tensor([26.2000]), tensor([0.])]},
#  {'diff': tensor([-63.9000]),
#   'episode_index': 61,
#   'timestamps': [tensor([63.9000]), tensor([0.])]},
#  {'diff': tensor([-47.3000]),
#   'episode_index': 62,
#   'timestamps': [tensor([47.3000]), tensor([0.])]},
#  {'diff': tensor([-43.1000]),
#   'episode_index': 63,
#   'timestamps': [tensor([43.1000]), tensor([0.])]},
#  {'diff': tensor([-41.]),
#   'episode_index': 64,
#   'timestamps': [tensor([41.]), tensor([0.])]},
#  {'diff': tensor([-41.8000]),
#   'episode_index': 65,
#   'timestamps': [tensor([41.8000]), tensor([0.])]},
#  {'diff': tensor([-43.3000]),
#   'episode_index': 66,
#   'timestamps': [tensor([43.3000]), tensor([0.])]},
#  {'diff': tensor([-39.8000]),
#   'episode_index': 67,
#   'timestamps': [tensor([39.8000]), tensor([0.])]},
#  {'diff': tensor([-40.3000]),
#   'episode_index': 68,
#   'timestamps': [tensor([40.3000]), tensor([0.])]},
#  {'diff': tensor([-33.4000]),
#   'episode_index': 69,
#   'timestamps': [tensor([33.4000]), tensor([0.])]},
#  {'diff': tensor([-42.4000]),
#   'episode_index': 70,
#   'timestamps': [tensor([42.4000]), tensor([0.])]},
#  {'diff': tensor([-45.3000]),
#   'episode_index': 71,
#   'timestamps': [tensor([45.3000]), tensor([0.])]},
#  {'diff': tensor([-43.6000]),
#   'episode_index': 72,
#   'timestamps': [tensor([43.6000]), tensor([0.])]},
#  {'diff': tensor([-55.4000]),
#   'episode_index': 73,
#   'timestamps': [tensor([55.4000]), tensor([0.])]},
#  {'diff': tensor([-36.7000]),
#   'episode_index': 74,
#   'timestamps': [tensor([36.7000]), tensor([0.])]},
#  {'diff': tensor([-61.2000]),
#   'episode_index': 75,
#   'timestamps': [tensor([61.2000]), tensor([0.])]},
#  {'diff': tensor([-35.4000]),
#   'episode_index': 76,
#   'timestamps': [tensor([35.4000]), tensor([0.])]},
#  {'diff': tensor([-44.8000]),
#   'episode_index': 77,
#   'timestamps': [tensor([44.8000]), tensor([0.])]},
#  {'diff': tensor([-28.9000]),
#   'episode_index': 78,
#   'timestamps': [tensor([28.9000]), tensor([0.])]},
#  {'diff': tensor([-37.4000]),
#   'episode_index': 79,
#   'timestamps': [tensor([37.4000]), tensor([0.])]},
#  {'diff': tensor([-35.2000]),
#   'episode_index': 80,
#   'timestamps': [tensor([35.2000]), tensor([0.])]},
#  {'diff': tensor([-50.2000]),
#   'episode_index': 81,
#   'timestamps': [tensor([50.2000]), tensor([0.])]},
#  {'diff': tensor([-29.8000]),
#   'episode_index': 82,
#   'timestamps': [tensor([29.8000]), tensor([0.])]},
#  {'diff': tensor([-58.]),
#   'episode_index': 83,
#   'timestamps': [tensor([58.]), tensor([0.])]},
#  {'diff': tensor([-18.8000]),
#   'episode_index': 84,
#   'timestamps': [tensor([18.8000]), tensor([0.])]},
#  {'diff': tensor([-28.1000]),
#   'episode_index': 85,
#   'timestamps': [tensor([28.1000]), tensor([0.])]},
#  {'diff': tensor([-66.5000]),
#   'episode_index': 86,
#   'timestamps': [tensor([66.5000]), tensor([0.])]},
#  {'diff': tensor([-40.2000]),
#   'episode_index': 87,
#   'timestamps': [tensor([40.2000]), tensor([0.])]},
#  {'diff': tensor([-30.4000]),
#   'episode_index': 88,
#   'timestamps': [tensor([30.4000]), tensor([0.])]},
#  {'diff': tensor([-44.6000]),
#   'episode_index': 89,
#   'timestamps': [tensor([44.6000]), tensor([0.])]},
#  {'diff': tensor([-29.4000]),
#   'episode_index': 90,
#   'timestamps': [tensor([29.4000]), tensor([0.])]},
#  {'diff': tensor([-75.7000]),
#   'episode_index': 91,
#   'timestamps': [tensor([75.7000]), tensor([0.])]},
#  {'diff': tensor([-36.]),
#   'episode_index': 92,
#   'timestamps': [tensor([36.]), tensor([0.])]},
#  {'diff': tensor([-51.8000]),
#   'episode_index': 93,
#   'timestamps': [tensor([51.8000]), tensor([0.])]},
#  {'diff': tensor([-36.8000]),
#   'episode_index': 94,
#   'timestamps': [tensor([36.8000]), tensor([0.])]},
#  {'diff': tensor([-22.3000]),
#   'episode_index': 95,
#   'timestamps': [tensor([22.3000]), tensor([0.])]},
#  {'diff': tensor([-32.7000]),
#   'episode_index': 96,
#   'timestamps': [tensor([32.7000]), tensor([0.])]},
#  {'diff': tensor([-43.6000]),
#   'episode_index': 97,
#   'timestamps': [tensor([43.6000]), tensor([0.])]},
#  {'diff': tensor([-36.7000]),
#   'episode_index': 98,
#   'timestamps': [tensor([36.7000]), tensor([0.])]},
#  {'diff': tensor([-33.5000]),
#   'episode_index': 99,
#   'timestamps': [tensor([33.5000]), tensor([0.])]},
#  {'diff': tensor([-70.6000]),
#   'episode_index': 100,
#   'timestamps': [tensor([70.6000]), tensor([0.])]},
#  {'diff': tensor([-40.9000]),
#   'episode_index': 101,
#   'timestamps': [tensor([40.9000]), tensor([0.])]},
#  {'diff': tensor([-30.7000]),
#   'episode_index': 102,
#   'timestamps': [tensor([30.7000]), tensor([0.])]},
#  {'diff': tensor([-35.2000]),
#   'episode_index': 103,
#   'timestamps': [tensor([35.2000]), tensor([0.])]},
#  {'diff': tensor([-28.2000]),
#   'episode_index': 104,
#   'timestamps': [tensor([28.2000]), tensor([0.])]},
#  {'diff': tensor([-44.]),
#   'episode_index': 105,
#   'timestamps': [tensor([44.]), tensor([0.])]},
#  {'diff': tensor([-39.7000]),
#   'episode_index': 106,
#   'timestamps': [tensor([39.7000]), tensor([0.])]},
#  {'diff': tensor([-42.6000]),
#   'episode_index': 107,
#   'timestamps': [tensor([42.6000]), tensor([0.])]},
#  {'diff': tensor([-31.7000]),
#   'episode_index': 108,
#   'timestamps': [tensor([31.7000]), tensor([0.])]},
#  {'diff': tensor([-32.3000]),
#   'episode_index': 109,
#   'timestamps': [tensor([32.3000]), tensor([0.])]},
#  {'diff': tensor([-47.1000]),
#   'episode_index': 110,
#   'timestamps': [tensor([47.1000]), tensor([0.])]},
#  {'diff': tensor([-25.]),
#   'episode_index': 111,
#   'timestamps': [tensor([25.]), tensor([0.])]},
#  {'diff': tensor([-23.9000]),
#   'episode_index': 112,
#   'timestamps': [tensor([23.9000]), tensor([0.])]},
#  {'diff': tensor([-27.7000]),
#   'episode_index': 113,
#   'timestamps': [tensor([27.7000]), tensor([0.])]},
#  {'diff': tensor([-34.2000]),
#   'episode_index': 114,
#   'timestamps': [tensor([34.2000]), tensor([0.])]},
#  {'diff': tensor([-24.2000]),
#   'episode_index': 115,
#   'timestamps': [tensor([24.2000]), tensor([0.])]},
#  {'diff': tensor([-60.9000]),
#   'episode_index': 116,
#   'timestamps': [tensor([60.9000]), tensor([0.])]},
#  {'diff': tensor([-35.5000]),
#   'episode_index': 117,
#   'timestamps': [tensor([35.5000]), tensor([0.])]},
#  {'diff': tensor([-33.4000]),
#   'episode_index': 118,
#   'timestamps': [tensor([33.4000]), tensor([0.])]},
#  {'diff': tensor([-33.2000]),
#   'episode_index': 119,
#   'timestamps': [tensor([33.2000]), tensor([0.])]},
#  {'diff': tensor([-33.1000]),
#   'episode_index': 120,
#   'timestamps': [tensor([33.1000]), tensor([0.])]},
#  {'diff': tensor([-46.3000]),
#   'episode_index': 121,
#   'timestamps': [tensor([46.3000]), tensor([0.])]},
#  {'diff': tensor([-19.8000]),
#   'episode_index': 122,
#   'timestamps': [tensor([19.8000]), tensor([0.])]},
#  {'diff': tensor([-37.7000]),
#   'episode_index': 123,
#   'timestamps': [tensor([37.7000]), tensor([0.])]},
#  {'diff': tensor([-42.8000]),
#   'episode_index': 124,
#   'timestamps': [tensor([42.8000]), tensor([0.])]},
#  {'diff': tensor([-40.7000]),
#   'episode_index': 125,
#   'timestamps': [tensor([40.7000]), tensor([0.])]},
#  {'diff': tensor([-29.1000]),
#   'episode_index': 126,
#   'timestamps': [tensor([29.1000]), tensor([0.])]},
#  {'diff': tensor([-20.]),
#   'episode_index': 127,
#   'timestamps': [tensor([20.]), tensor([0.])]},
#  {'diff': tensor([-23.7000]),
#   'episode_index': 128,
#   'timestamps': [tensor([23.7000]), tensor([0.])]},
#  {'diff': tensor([-63.1000]),
#   'episode_index': 129,
#   'timestamps': [tensor([63.1000]), tensor([0.])]},
#  {'diff': tensor([-21.7000]),
#   'episode_index': 130,
#   'timestamps': [tensor([21.7000]), tensor([0.])]},
#  {'diff': tensor([-46.1000]),
#   'episode_index': 131,
#   'timestamps': [tensor([46.1000]), tensor([0.])]},
#  {'diff': tensor([-24.5000]),
#   'episode_index': 132,
#   'timestamps': [tensor([24.5000]), tensor([0.])]},
#  {'diff': tensor([-26.1000]),
#   'episode_index': 133,
#   'timestamps': [tensor([26.1000]), tensor([0.])]},
#  {'diff': tensor([-20.1000]),
#   'episode_index': 134,
#   'timestamps': [tensor([20.1000]), tensor([0.])]},
#  {'diff': tensor([-45.5000]),
#   'episode_index': 135,
#   'timestamps': [tensor([45.5000]), tensor([0.])]},
#  {'diff': tensor([-46.4000]),
#   'episode_index': 136,
#   'timestamps': [tensor([46.4000]), tensor([0.])]},
#  {'diff': tensor([-26.3000]),
#   'episode_index': 137,
#   'timestamps': [tensor([26.3000]), tensor([0.])]},
#  {'diff': tensor([-41.2000]),
#   'episode_index': 138,
#   'timestamps': [tensor([41.2000]), tensor([0.])]},
#  {'diff': tensor([-49.2000]),
#   'episode_index': 139,
#   'timestamps': [tensor([49.2000]), tensor([0.])]},
#  {'diff': tensor([-48.2000]),
#   'episode_index': 140,
#   'timestamps': [tensor([48.2000]), tensor([0.])]},
#  {'diff': tensor([-30.2000]),
#   'episode_index': 141,
#   'timestamps': [tensor([30.2000]), tensor([0.])]},
#  {'diff': tensor([-51.1000]),
#   'episode_index': 142,
#   'timestamps': [tensor([51.1000]), tensor([0.])]},
#  {'diff': tensor([-46.1000]),
#   'episode_index': 143,
#   'timestamps': [tensor([46.1000]), tensor([0.])]},
#  {'diff': tensor([-31.4000]),
#   'episode_index': 144,
#   'timestamps': [tensor([31.4000]), tensor([0.])]},
#  {'diff': tensor([-36.2000]),
#   'episode_index': 145,
#   'timestamps': [tensor([36.2000]), tensor([0.])]},
#  {'diff': tensor([-56.]),
#   'episode_index': 146,
#   'timestamps': [tensor([56.]), tensor([0.])]},
#  {'diff': tensor([-58.8000]),
#   'episode_index': 147,
#   'timestamps': [tensor([58.8000]), tensor([0.])]},
#  {'diff': tensor([-46.2000]),
#   'episode_index': 148,
#   'timestamps': [tensor([46.2000]), tensor([0.])]},
#  {'diff': tensor([-53.]),
#   'episode_index': 149,
#   'timestamps': [tensor([53.]), tensor([0.])]},
#  {'diff': tensor([-43.3000]),
#   'episode_index': 150,
#   'timestamps': [tensor([43.3000]), tensor([0.])]},
#  {'diff': tensor([-38.]),
#   'episode_index': 151,
#   'timestamps': [tensor([38.]), tensor([0.])]},
#  {'diff': tensor([-29.]),
#   'episode_index': 152,
#   'timestamps': [tensor([29.]), tensor([0.])]},
#  {'diff': tensor([-35.6000]),
#   'episode_index': 153,
#   'timestamps': [tensor([35.6000]), tensor([0.])]},
#  {'diff': tensor([-24.8000]),
#   'episode_index': 154,
#   'timestamps': [tensor([24.8000]), tensor([0.])]},
#  {'diff': tensor([-33.8000]),
#   'episode_index': 155,
#   'timestamps': [tensor([33.8000]), tensor([0.])]},
#  {'diff': tensor([-25.9000]),
#   'episode_index': 156,
#   'timestamps': [tensor([25.9000]), tensor([0.])]},
#  {'diff': tensor([-35.]),
#   'episode_index': 157,
#   'timestamps': [tensor([35.]), tensor([0.])]},
#  {'diff': tensor([-59.5000]),
#   'episode_index': 158,
#   'timestamps': [tensor([59.5000]), tensor([0.])]},
#  {'diff': tensor([-42.3000]),
#   'episode_index': 159,
#   'timestamps': [tensor([42.3000]), tensor([0.])]},
#  {'diff': tensor([-48.2000]),
#   'episode_index': 160,
#   'timestamps': [tensor([48.2000]), tensor([0.])]},
#  {'diff': tensor([-43.4000]),
#   'episode_index': 161,
#   'timestamps': [tensor([43.4000]), tensor([0.])]},
#  {'diff': tensor([-52.1000]),
#   'episode_index': 162,
#   'timestamps': [tensor([52.1000]), tensor([0.])]},
#  {'diff': tensor([-27.8000]),
#   'episode_index': 163,
#   'timestamps': [tensor([27.8000]), tensor([0.])]},
#  {'diff': tensor([-33.5000]),
#   'episode_index': 164,
#   'timestamps': [tensor([33.5000]), tensor([0.])]},
#  {'diff': tensor([-43.9000]),
#   'episode_index': 165,
#   'timestamps': [tensor([43.9000]), tensor([0.])]},
#  {'diff': tensor([-28.6000]),
#   'episode_index': 166,
#   'timestamps': [tensor([28.6000]), tensor([0.])]},
#  {'diff': tensor([-49.9000]),
#   'episode_index': 167,
#   'timestamps': [tensor([49.9000]), tensor([0.])]},
#  {'diff': tensor([-55.7000]),
#   'episode_index': 168,
#   'timestamps': [tensor([55.7000]), tensor([0.])]},
#  {'diff': tensor([-46.1000]),
#   'episode_index': 169,
#   'timestamps': [tensor([46.1000]), tensor([0.])]},
#  {'diff': tensor([-25.1000]),
#   'episode_index': 170,
#   'timestamps': [tensor([25.1000]), tensor([0.])]},
#  {'diff': tensor([-41.1000]),
#   'episode_index': 171,
#   'timestamps': [tensor([41.1000]), tensor([0.])]},
#  {'diff': tensor([-27.5000]),
#   'episode_index': 172,
#   'timestamps': [tensor([27.5000]), tensor([0.])]},
#  {'diff': tensor([-38.6000]),
#   'episode_index': 173,
#   'timestamps': [tensor([38.6000]), tensor([0.])]},
#  {'diff': tensor([-32.3000]),
#   'episode_index': 174,
#   'timestamps': [tensor([32.3000]), tensor([0.])]},
#  {'diff': tensor([-46.6000]),
#   'episode_index': 175,
#   'timestamps': [tensor([46.6000]), tensor([0.])]},
#  {'diff': tensor([-34.7000]),
#   'episode_index': 176,
#   'timestamps': [tensor([34.7000]), tensor([0.])]},
#  {'diff': tensor([-45.9000]),
#   'episode_index': 177,
#   'timestamps': [tensor([45.9000]), tensor([0.])]},
#  {'diff': tensor([-31.3000]),
#   'episode_index': 178,
#   'timestamps': [tensor([31.3000]), tensor([0.])]},
#  {'diff': tensor([-30.3000]),
#   'episode_index': 179,
#   'timestamps': [tensor([30.3000]), tensor([0.])]},
#  {'diff': tensor([-33.3000]),
#   'episode_index': 180,
#   'timestamps': [tensor([33.3000]), tensor([0.])]},
#  {'diff': tensor([-44.1000]),
#   'episode_index': 181,
#   'timestamps': [tensor([44.1000]), tensor([0.])]},
#  {'diff': tensor([-30.]),
#   'episode_index': 182,
#   'timestamps': [tensor([30.]), tensor([0.])]},
#  {'diff': tensor([-39.5000]),
#   'episode_index': 183,
#   'timestamps': [tensor([39.5000]), tensor([0.])]},
#  {'diff': tensor([-33.1000]),
#   'episode_index': 184,
#   'timestamps': [tensor([33.1000]), tensor([0.])]},
#  {'diff': tensor([-33.1000]),
#   'episode_index': 185,
#   'timestamps': [tensor([33.1000]), tensor([0.])]},
#  {'diff': tensor([-21.5000]),
#   'episode_index': 186,
#   'timestamps': [tensor([21.5000]), tensor([0.])]},
#  {'diff': tensor([-65.2000]),
#   'episode_index': 187,
#   'timestamps': [tensor([65.2000]), tensor([0.])]},
#  {'diff': tensor([-35.3000]),
#   'episode_index': 188,
#   'timestamps': [tensor([35.3000]), tensor([0.])]},
#  {'diff': tensor([-40.8000]),
#   'episode_index': 189,
#   'timestamps': [tensor([40.8000]), tensor([0.])]},
#  {'diff': tensor([-48.9000]),
#   'episode_index': 190,
#   'timestamps': [tensor([48.9000]), tensor([0.])]},
#  {'diff': tensor([-35.8000]),
#   'episode_index': 191,
#   'timestamps': [tensor([35.8000]), tensor([0.])]},
#  {'diff': tensor([-37.6000]),
#   'episode_index': 192,
#   'timestamps': [tensor([37.6000]), tensor([0.])]},
#  {'diff': tensor([-22.3000]),
#   'episode_index': 193,
#   'timestamps': [tensor([22.3000]), tensor([0.])]},
#  {'diff': tensor([-34.]),
#   'episode_index': 194,
#   'timestamps': [tensor([34.]), tensor([0.])]},
#  {'diff': tensor([-41.7000]),
#   'episode_index': 195,
#   'timestamps': [tensor([41.7000]), tensor([0.])]},
#  {'diff': tensor([-34.3000]),
#   'episode_index': 196,
#   'timestamps': [tensor([34.3000]), tensor([0.])]},
#  {'diff': tensor([-43.8000]),
#   'episode_index': 197,
#   'timestamps': [tensor([43.8000]), tensor([0.])]},
#  {'diff': tensor([-29.4000]),
#   'episode_index': 198,
#   'timestamps': [tensor([29.4000]), tensor([0.])]},
#  {'diff': tensor([-33.5000]),
#   'episode_index': 199,
#   'timestamps': [tensor([33.5000]), tensor([0.])]},
#  {'diff': tensor([-42.2000]),
#   'episode_index': 200,
#   'timestamps': [tensor([42.2000]), tensor([0.])]},
#  {'diff': tensor([-36.1000]),
#   'episode_index': 201,
#   'timestamps': [tensor([36.1000]), tensor([0.])]},
#  {'diff': tensor([-31.9000]),
#   'episode_index': 202,
#   'timestamps': [tensor([31.9000]), tensor([0.])]},
#  {'diff': tensor([-31.4000]),
#   'episode_index': 203,
#   'timestamps': [tensor([31.4000]), tensor([0.])]},
#  {'diff': tensor([-53.]),
#   'episode_index': 204,
#   'timestamps': [tensor([53.]), tensor([0.])]},
#  {'diff': tensor([-37.8000]),
#   'episode_index': 205,
#   'timestamps': [tensor([37.8000]), tensor([0.])]},
#  {'diff': tensor([-63.1000]),
#   'episode_index': 206,
#   'timestamps': [tensor([63.1000]), tensor([0.])]},
#  {'diff': tensor([-56.4000]),
#   'episode_index': 207,
#   'timestamps': [tensor([56.4000]), tensor([0.])]},
#  {'diff': tensor([-25.4000]),
#   'episode_index': 208,
#   'timestamps': [tensor([25.4000]), tensor([0.])]},
#  {'diff': tensor([-35.3000]),
#   'episode_index': 209,
#   'timestamps': [tensor([35.3000]), tensor([0.])]},
#  {'diff': tensor([-30.6000]),
#   'episode_index': 210,
#   'timestamps': [tensor([30.6000]), tensor([0.])]},
#  {'diff': tensor([-50.1000]),
#   'episode_index': 211,
#   'timestamps': [tensor([50.1000]), tensor([0.])]},
#  {'diff': tensor([-37.6000]),
#   'episode_index': 212,
#   'timestamps': [tensor([37.6000]), tensor([0.])]},
#  {'diff': tensor([-32.9000]),
#   'episode_index': 213,
#   'timestamps': [tensor([32.9000]), tensor([0.])]},
#  {'diff': tensor([-51.9000]),
#   'episode_index': 214,
#   'timestamps': [tensor([51.9000]), tensor([0.])]},
#  {'diff': tensor([-31.2000]),
#   'episode_index': 215,
#   'timestamps': [tensor([31.2000]), tensor([0.])]},
#  {'diff': tensor([-31.4000]),
#   'episode_index': 216,
#   'timestamps': [tensor([31.4000]), tensor([0.])]},
#  {'diff': tensor([-50.8000]),
#   'episode_index': 217,
#   'timestamps': [tensor([50.8000]), tensor([0.])]},
#  {'diff': tensor([-44.5000]),
#   'episode_index': 218,
#   'timestamps': [tensor([44.5000]), tensor([0.])]},
#  {'diff': tensor([-46.6000]),
#   'episode_index': 219,
#   'timestamps': [tensor([46.6000]), tensor([0.])]},
#  {'diff': tensor([-23.3000]),
#   'episode_index': 220,
#   'timestamps': [tensor([23.3000]), tensor([0.])]},
#  {'diff': tensor([-30.5000]),
#   'episode_index': 221,
#   'timestamps': [tensor([30.5000]), tensor([0.])]},
#  {'diff': tensor([-31.]),
#   'episode_index': 222,
#   'timestamps': [tensor([31.]), tensor([0.])]},
#  {'diff': tensor([-34.1000]),
#   'episode_index': 223,
#   'timestamps': [tensor([34.1000]), tensor([0.])]},
#  {'diff': tensor([-28.4000]),
#   'episode_index': 224,
#   'timestamps': [tensor([28.4000]), tensor([0.])]},
#  {'diff': tensor([-34.4000]),
#   'episode_index': 225,
#   'timestamps': [tensor([34.4000]), tensor([0.])]},
#  {'diff': tensor([-57.4000]),
#   'episode_index': 226,
#   'timestamps': [tensor([57.4000]), tensor([0.])]},
#  {'diff': tensor([-27.8000]),
#   'episode_index': 227,
#   'timestamps': [tensor([27.8000]), tensor([0.])]},
#  {'diff': tensor([-34.5000]),
#   'episode_index': 228,
#   'timestamps': [tensor([34.5000]), tensor([0.])]},
#  {'diff': tensor([-40.9000]),
#   'episode_index': 229,
#   'timestamps': [tensor([40.9000]), tensor([0.])]},
#  {'diff': tensor([-37.]),
#   'episode_index': 230,
#   'timestamps': [tensor([37.]), tensor([0.])]},
#  {'diff': tensor([-33.5000]),
#   'episode_index': 231,
#   'timestamps': [tensor([33.5000]), tensor([0.])]},
#  {'diff': tensor([-33.3000]),
#   'episode_index': 232,
#   'timestamps': [tensor([33.3000]), tensor([0.])]},
#  {'diff': tensor([-36.2000]),
#   'episode_index': 233,
#   'timestamps': [tensor([36.2000]), tensor([0.])]},
#  {'diff': tensor([-61.2000]),
#   'episode_index': 234,
#   'timestamps': [tensor([61.2000]), tensor([0.])]},
#  {'diff': tensor([-39.2000]),
#   'episode_index': 235,
#   'timestamps': [tensor([39.2000]), tensor([0.])]},
#  {'diff': tensor([-42.2000]),
#   'episode_index': 236,
#   'timestamps': [tensor([42.2000]), tensor([0.])]},
#  {'diff': tensor([-46.]),
#   'episode_index': 237,
#   'timestamps': [tensor([46.]), tensor([0.])]},
#  {'diff': tensor([-45.6000]),
#   'episode_index': 238,
#   'timestamps': [tensor([45.6000]), tensor([0.])]},
#  {'diff': tensor([-35.]),
#   'episode_index': 239,
#   'timestamps': [tensor([35.]), tensor([0.])]},
#  {'diff': tensor([-61.9000]),
#   'episode_index': 240,
#   'timestamps': [tensor([61.9000]), tensor([0.])]},
#  {'diff': tensor([-33.2000]),
#   'episode_index': 241,
#   'timestamps': [tensor([33.2000]), tensor([0.])]},
#  {'diff': tensor([-48.4000]),
#   'episode_index': 242,
#   'timestamps': [tensor([48.4000]), tensor([0.])]},
#  {'diff': tensor([-26.6000]),
#   'episode_index': 243,
#   'timestamps': [tensor([26.6000]), tensor([0.])]},
#  {'diff': tensor([-35.4000]),
#   'episode_index': 244,
#   'timestamps': [tensor([35.4000]), tensor([0.])]},
#  {'diff': tensor([-45.2000]),
#   'episode_index': 245,
#   'timestamps': [tensor([45.2000]), tensor([0.])]},
#  {'diff': tensor([-35.4000]),
#   'episode_index': 246,
#   'timestamps': [tensor([35.4000]), tensor([0.])]},
#  {'diff': tensor([-40.3000]),
#   'episode_index': 247,
#   'timestamps': [tensor([40.3000]), tensor([0.])]},
#  {'diff': tensor([-34.7000]),
#   'episode_index': 248,
#   'timestamps': [tensor([34.7000]), tensor([0.])]},
#  {'diff': tensor([-39.8000]),
#   'episode_index': 249,
#   'timestamps': [tensor([39.8000]), tensor([0.])]},
#  {'diff': tensor([-32.4000]),
#   'episode_index': 250,
#   'timestamps': [tensor([32.4000]), tensor([0.])]},
#  {'diff': tensor([-45.4000]),
#   'episode_index': 251,
#   'timestamps': [tensor([45.4000]), tensor([0.])]},
#  {'diff': tensor([-49.8000]),
#   'episode_index': 252,
#   'timestamps': [tensor([49.8000]), tensor([0.])]},
#  {'diff': tensor([-30.8000]),
#   'episode_index': 253,
#   'timestamps': [tensor([30.8000]), tensor([0.])]},
#  {'diff': tensor([-33.2000]),
#   'episode_index': 254,
#   'timestamps': [tensor([33.2000]), tensor([0.])]},
#  {'diff': tensor([-33.6000]),
#   'episode_index': 255,
#   'timestamps': [tensor([33.6000]), tensor([0.])]},
#  {'diff': tensor([-47.3000]),
#   'episode_index': 256,
#   'timestamps': [tensor([47.3000]), tensor([0.])]},
#  {'diff': tensor([-33.3000]),
#   'episode_index': 257,
#   'timestamps': [tensor([33.3000]), tensor([0.])]},
#  {'diff': tensor([-35.9000]),
#   'episode_index': 258,
#   'timestamps': [tensor([35.9000]), tensor([0.])]},
#  {'diff': tensor([-25.9000]),
#   'episode_index': 259,
#   'timestamps': [tensor([25.9000]), tensor([0.])]},
#  {'diff': tensor([-50.8000]),
#   'episode_index': 260,
#   'timestamps': [tensor([50.8000]), tensor([0.])]},
#  {'diff': tensor([-49.4000]),
#   'episode_index': 261,
#   'timestamps': [tensor([49.4000]), tensor([0.])]},
#  {'diff': tensor([-28.5000]),
#   'episode_index': 262,
#   'timestamps': [tensor([28.5000]), tensor([0.])]},
#  {'diff': tensor([-22.9000]),
#   'episode_index': 263,
#   'timestamps': [tensor([22.9000]), tensor([0.])]},
#  {'diff': tensor([-40.4000]),
#   'episode_index': 264,
#   'timestamps': [tensor([40.4000]), tensor([0.])]},
#  {'diff': tensor([-46.1000]),
#   'episode_index': 265,
#   'timestamps': [tensor([46.1000]), tensor([0.])]},
#  {'diff': tensor([-41.4000]),
#   'episode_index': 266,
#   'timestamps': [tensor([41.4000]), tensor([0.])]},
#  {'diff': tensor([-37.3000]),
#   'episode_index': 267,
#   'timestamps': [tensor([37.3000]), tensor([0.])]},
#  {'diff': tensor([-25.8000]),
#   'episode_index': 268,
#   'timestamps': [tensor([25.8000]), tensor([0.])]},
#  {'diff': tensor([-49.8000]),
#   'episode_index': 269,
#   'timestamps': [tensor([49.8000]), tensor([0.])]},
#  {'diff': tensor([-41.8000]),
#   'episode_index': 270,
#   'timestamps': [tensor([41.8000]), tensor([0.])]},
#  {'diff': tensor([-35.1000]),
#   'episode_index': 271,
#   'timestamps': [tensor([35.1000]), tensor([0.])]},
#  {'diff': tensor([-26.3000]),
#   'episode_index': 272,
#   'timestamps': [tensor([26.3000]), tensor([0.])]},
#  {'diff': tensor([-22.6000]),
#   'episode_index': 273,
#   'timestamps': [tensor([22.6000]), tensor([0.])]},
#  {'diff': tensor([-31.5000]),
#   'episode_index': 274,
#   'timestamps': [tensor([31.5000]), tensor([0.])]},
#  {'diff': tensor([-43.8000]),
#   'episode_index': 275,
#   'timestamps': [tensor([43.8000]), tensor([0.])]},
#  {'diff': tensor([-20.8000]),
#   'episode_index': 276,
#   'timestamps': [tensor([20.8000]), tensor([0.])]},
#  {'diff': tensor([-33.8000]),
#   'episode_index': 277,
#   'timestamps': [tensor([33.8000]), tensor([0.])]},
#  {'diff': tensor([-44.3000]),
#   'episode_index': 278,
#   'timestamps': [tensor([44.3000]), tensor([0.])]},
#  {'diff': tensor([-27.]),
#   'episode_index': 279,
#   'timestamps': [tensor([27.]), tensor([0.])]},
#  {'diff': tensor([-24.8000]),
#   'episode_index': 280,
#   'timestamps': [tensor([24.8000]), tensor([0.])]},
#  {'diff': tensor([-26.5000]),
#   'episode_index': 281,
#   'timestamps': [tensor([26.5000]), tensor([0.])]},
#  {'diff': tensor([-25.6000]),
#   'episode_index': 282,
#   'timestamps': [tensor([25.6000]), tensor([0.])]},
#  {'diff': tensor([-38.3000]),
#   'episode_index': 283,
#   'timestamps': [tensor([38.3000]), tensor([0.])]},
#  {'diff': tensor([-29.8000]),
#   'episode_index': 284,
#   'timestamps': [tensor([29.8000]), tensor([0.])]},
#  {'diff': tensor([-42.6000]),
#   'episode_index': 285,
#   'timestamps': [tensor([42.6000]), tensor([0.])]},
#  {'diff': tensor([-47.2000]),
#   'episode_index': 286,
#   'timestamps': [tensor([47.2000]), tensor([0.])]},
#  {'diff': tensor([-26.7000]),
#   'episode_index': 287,
#   'timestamps': [tensor([26.7000]), tensor([0.])]},
#  {'diff': tensor([-44.7000]),
#   'episode_index': 288,
#   'timestamps': [tensor([44.7000]), tensor([0.])]},
#  {'diff': tensor([-23.8000]),
#   'episode_index': 289,
#   'timestamps': [tensor([23.8000]), tensor([0.])]},
#  {'diff': tensor([-24.3000]),
#   'episode_index': 290,
#   'timestamps': [tensor([24.3000]), tensor([0.])]},
#  {'diff': tensor([-24.1000]),
#   'episode_index': 291,
#   'timestamps': [tensor([24.1000]), tensor([0.])]},
#  {'diff': tensor([-20.3000]),
#   'episode_index': 292,
#   'timestamps': [tensor([20.3000]), tensor([0.])]},
#  {'diff': tensor([-21.4000]),
#   'episode_index': 293,
#   'timestamps': [tensor([21.4000]), tensor([0.])]},
#  {'diff': tensor([-22.4000]),
#   'episode_index': 294,
#   'timestamps': [tensor([22.4000]), tensor([0.])]},
#  {'diff': tensor([-30.4000]),
#   'episode_index': 295,
#   'timestamps': [tensor([30.4000]), tensor([0.])]},
#  {'diff': tensor([-14.1000]),
#   'episode_index': 296,
#   'timestamps': [tensor([14.1000]), tensor([0.])]},
#  {'diff': tensor([-23.4000]),
#   'episode_index': 297,
#   'timestamps': [tensor([23.4000]), tensor([0.])]},
#  {'diff': tensor([-20.2000]),
#   'episode_index': 298,
#   'timestamps': [tensor([20.2000]), tensor([0.])]},
#  {'diff': tensor([-31.6000]),
#   'episode_index': 299,
#   'timestamps': [tensor([31.6000]), tensor([0.])]},
#  {'diff': tensor([-33.3000]),
#   'episode_index': 300,
#   'timestamps': [tensor([33.3000]), tensor([0.])]},
#  {'diff': tensor([-23.1000]),
#   'episode_index': 301,
#   'timestamps': [tensor([23.1000]), tensor([0.])]},
#  {'diff': tensor([-24.7000]),
#   'episode_index': 302,
#   'timestamps': [tensor([24.7000]), tensor([0.])]},
#  {'diff': tensor([-37.2000]),
#   'episode_index': 303,
#   'timestamps': [tensor([37.2000]), tensor([0.])]},
#  {'diff': tensor([-29.5000]),
#   'episode_index': 304,
#   'timestamps': [tensor([29.5000]), tensor([0.])]},
#  {'diff': tensor([-37.]),
#   'episode_index': 305,
#   'timestamps': [tensor([37.]), tensor([0.])]},
#  {'diff': tensor([-30.6000]),
#   'episode_index': 306,
#   'timestamps': [tensor([30.6000]), tensor([0.])]},
#  {'diff': tensor([-45.]),
#   'episode_index': 307,
#   'timestamps': [tensor([45.]), tensor([0.])]},
#  {'diff': tensor([-43.1000]),
#   'episode_index': 308,
#   'timestamps': [tensor([43.1000]), tensor([0.])]},
#  {'diff': tensor([-32.1000]),
#   'episode_index': 309,
#   'timestamps': [tensor([32.1000]), tensor([0.])]},
#  {'diff': tensor([-38.7000]),
#   'episode_index': 310,
#   'timestamps': [tensor([38.7000]), tensor([0.])]},
#  {'diff': tensor([-32.5000]),
#   'episode_index': 311,
#   'timestamps': [tensor([32.5000]), tensor([0.])]},
#  {'diff': tensor([-34.6000]),
#   'episode_index': 312,
#   'timestamps': [tensor([34.6000]), tensor([0.])]},
#  {'diff': tensor([-27.5000]),
#   'episode_index': 313,
#   'timestamps': [tensor([27.5000]), tensor([0.])]},
#  {'diff': tensor([-31.8000]),
#   'episode_index': 314,
#   'timestamps': [tensor([31.8000]), tensor([0.])]},
#  {'diff': tensor([-39.]),
#   'episode_index': 315,
#   'timestamps': [tensor([39.]), tensor([0.])]},
#  {'diff': tensor([-43.4000]),
#   'episode_index': 316,
#   'timestamps': [tensor([43.4000]), tensor([0.])]},
#  {'diff': tensor([-27.3000]),
#   'episode_index': 317,
#   'timestamps': [tensor([27.3000]), tensor([0.])]},
#  {'diff': tensor([-38.1000]),
#   'episode_index': 318,
#   'timestamps': [tensor([38.1000]), tensor([0.])]},
#  {'diff': tensor([-64.3000]),
#   'episode_index': 319,
#   'timestamps': [tensor([64.3000]), tensor([0.])]},
#  {'diff': tensor([-28.]),
#   'episode_index': 320,
#   'timestamps': [tensor([28.]), tensor([0.])]},
#  {'diff': tensor([-39.]),
#   'episode_index': 321,
#   'timestamps': [tensor([39.]), tensor([0.])]},
#  {'diff': tensor([-35.8000]),
#   'episode_index': 322,
#   'timestamps': [tensor([35.8000]), tensor([0.])]},
#  {'diff': tensor([-62.4000]),
#   'episode_index': 323,
#   'timestamps': [tensor([62.4000]), tensor([0.])]},
#  {'diff': tensor([-46.2000]),
#   'episode_index': 324,
#   'timestamps': [tensor([46.2000]), tensor([0.])]},
#  {'diff': tensor([-29.5000]),
#   'episode_index': 325,
#   'timestamps': [tensor([29.5000]), tensor([0.])]},
#  {'diff': tensor([-35.]),
#   'episode_index': 326,
#   'timestamps': [tensor([35.]), tensor([0.])]},
#  {'diff': tensor([-47.3000]),
#   'episode_index': 327,
#   'timestamps': [tensor([47.3000]), tensor([0.])]},
#  {'diff': tensor([-34.]),
#   'episode_index': 328,
#   'timestamps': [tensor([34.]), tensor([0.])]},
#  {'diff': tensor([-40.8000]),
#   'episode_index': 329,
#   'timestamps': [tensor([40.8000]), tensor([0.])]},
#  {'diff': tensor([-42.1000]),
#   'episode_index': 330,
#   'timestamps': [tensor([42.1000]), tensor([0.])]},
#  {'diff': tensor([-37.5000]),
#   'episode_index': 331,
#   'timestamps': [tensor([37.5000]), tensor([0.])]},
#  {'diff': tensor([-42.5000]),
#   'episode_index': 332,
#   'timestamps': [tensor([42.5000]), tensor([0.])]},
#  {'diff': tensor([-36.8000]),
#   'episode_index': 333,
#   'timestamps': [tensor([36.8000]), tensor([0.])]},
#  {'diff': tensor([-35.9000]),
#   'episode_index': 334,
#   'timestamps': [tensor([35.9000]), tensor([0.])]},
#  {'diff': tensor([-56.3000]),
#   'episode_index': 335,
#   'timestamps': [tensor([56.3000]), tensor([0.])]},
#  {'diff': tensor([-68.4000]),
#   'episode_index': 336,
#   'timestamps': [tensor([68.4000]), tensor([0.])]},
#  {'diff': tensor([-51.6000]),
#   'episode_index': 337,
#   'timestamps': [tensor([51.6000]), tensor([0.])]},
#  {'diff': tensor([-48.1000]),
#   'episode_index': 338,
#   'timestamps': [tensor([48.1000]), tensor([0.])]},
#  {'diff': tensor([-28.6000]),
#   'episode_index': 339,
#   'timestamps': [tensor([28.6000]), tensor([0.])]},
#  {'diff': tensor([-44.5000]),
#   'episode_index': 340,
#   'timestamps': [tensor([44.5000]), tensor([0.])]},
#  {'diff': tensor([-42.1000]),
#   'episode_index': 341,
#   'timestamps': [tensor([42.1000]), tensor([0.])]},
#  {'diff': tensor([-28.]),
#   'episode_index': 342,
#   'timestamps': [tensor([28.]), tensor([0.])]},
#  {'diff': tensor([-34.8000]),
#   'episode_index': 343,
#   'timestamps': [tensor([34.8000]), tensor([0.])]},
#  {'diff': tensor([-37.4000]),
#   'episode_index': 344,
#   'timestamps': [tensor([37.4000]), tensor([0.])]},
#  {'diff': tensor([-30.5000]),
#   'episode_index': 345,
#   'timestamps': [tensor([30.5000]), tensor([0.])]},
#  {'diff': tensor([-33.9000]),
#   'episode_index': 346,
#   'timestamps': [tensor([33.9000]), tensor([0.])]},
#  {'diff': tensor([-44.9000]),
#   'episode_index': 347,
#   'timestamps': [tensor([44.9000]), tensor([0.])]},
#  {'diff': tensor([-41.4000]),
#   'episode_index': 348,
#   'timestamps': [tensor([41.4000]), tensor([0.])]},
#  {'diff': tensor([-57.1000]),
#   'episode_index': 349,
#   'timestamps': [tensor([57.1000]), tensor([0.])]},
#  {'diff': tensor([-88.6000]),
#   'episode_index': 350,
#   'timestamps': [tensor([88.6000]), tensor([0.])]},
#  {'diff': tensor([-42.3000]),
#   'episode_index': 351,
#   'timestamps': [tensor([42.3000]), tensor([0.])]},
#  {'diff': tensor([-44.1000]),
#   'episode_index': 352,
#   'timestamps': [tensor([44.1000]), tensor([0.])]},
#  {'diff': tensor([-58.5000]),
#   'episode_index': 353,
#   'timestamps': [tensor([58.5000]), tensor([0.])]},
#  {'diff': tensor([-48.5000]),
#   'episode_index': 354,
#   'timestamps': [tensor([48.5000]), tensor([0.])]},
#  {'diff': tensor([-38.5000]),
#   'episode_index': 355,
#   'timestamps': [tensor([38.5000]), tensor([0.])]},
#  {'diff': tensor([-33.5000]),
#   'episode_index': 356,
#   'timestamps': [tensor([33.5000]), tensor([0.])]},
#  {'diff': tensor([-39.3000]),
#   'episode_index': 357,
#   'timestamps': [tensor([39.3000]), tensor([0.])]},
#  {'diff': tensor([-53.]),
#   'episode_index': 358,
#   'timestamps': [tensor([53.]), tensor([0.])]},
#  {'diff': tensor([-55.8000]),
#   'episode_index': 359,
#   'timestamps': [tensor([55.8000]), tensor([0.])]},
#  {'diff': tensor([-28.9000]),
#   'episode_index': 360,
#   'timestamps': [tensor([28.9000]), tensor([0.])]},
#  {'diff': tensor([-27.3000]),
#   'episode_index': 361,
#   'timestamps': [tensor([27.3000]), tensor([0.])]},
#  {'diff': tensor([-54.6000]),
#   'episode_index': 362,
#   'timestamps': [tensor([54.6000]), tensor([0.])]},
#  {'diff': tensor([-35.5000]),
#   'episode_index': 363,
#   'timestamps': [tensor([35.5000]), tensor([0.])]},
#  {'diff': tensor([-37.3000]),
#   'episode_index': 364,
#   'timestamps': [tensor([37.3000]), tensor([0.])]},
#  {'diff': tensor([-27.4000]),
#   'episode_index': 365,
#   'timestamps': [tensor([27.4000]), tensor([0.])]},
#  {'diff': tensor([-39.2000]),
#   'episode_index': 366,
#   'timestamps': [tensor([39.2000]), tensor([0.])]},
#  {'diff': tensor([-39.8000]),
#   'episode_index': 367,
#   'timestamps': [tensor([39.8000]), tensor([0.])]},
#  {'diff': tensor([-37.6000]),
#   'episode_index': 368,
#   'timestamps': [tensor([37.6000]), tensor([0.])]},
#  {'diff': tensor([-42.5000]),
#   'episode_index': 369,
#   'timestamps': [tensor([42.5000]), tensor([0.])]},
#  {'diff': tensor([-48.2000]),
#   'episode_index': 370,
#   'timestamps': [tensor([48.2000]), tensor([0.])]},
#  {'diff': tensor([-30.7000]),
#   'episode_index': 371,
#   'timestamps': [tensor([30.7000]), tensor([0.])]},
#  {'diff': tensor([-46.3000]),
#   'episode_index': 372,
#   'timestamps': [tensor([46.3000]), tensor([0.])]},
#  {'diff': tensor([-47.4000]),
#   'episode_index': 373,
#   'timestamps': [tensor([47.4000]), tensor([0.])]},
#  {'diff': tensor([-48.7000]),
#   'episode_index': 374,
#   'timestamps': [tensor([48.7000]), tensor([0.])]},
#  {'diff': tensor([-43.]),
#   'episode_index': 375,
#   'timestamps': [tensor([43.]), tensor([0.])]},
#  {'diff': tensor([-41.4000]),
#   'episode_index': 376,
#   'timestamps': [tensor([41.4000]), tensor([0.])]},
#  {'diff': tensor([-22.9000]),
#   'episode_index': 377,
#   'timestamps': [tensor([22.9000]), tensor([0.])]},
#  {'diff': tensor([-53.2000]),
#   'episode_index': 378,
#   'timestamps': [tensor([53.2000]), tensor([0.])]},
#  {'diff': tensor([-29.4000]),
#   'episode_index': 379,
#   'timestamps': [tensor([29.4000]), tensor([0.])]},
#  {'diff': tensor([-61.1000]),
#   'episode_index': 380,
#   'timestamps': [tensor([61.1000]), tensor([0.])]},
#  {'diff': tensor([-28.3000]),
#   'episode_index': 381,
#   'timestamps': [tensor([28.3000]), tensor([0.])]},
#  {'diff': tensor([-55.9000]),
#   'episode_index': 382,
#   'timestamps': [tensor([55.9000]), tensor([0.])]},
#  {'diff': tensor([-37.2000]),
#   'episode_index': 383,
#   'timestamps': [tensor([37.2000]), tensor([0.])]},
#  {'diff': tensor([-43.4000]),
#   'episode_index': 384,
#   'timestamps': [tensor([43.4000]), tensor([0.])]},
#  {'diff': tensor([-28.6000]),
#   'episode_index': 385,
#   'timestamps': [tensor([28.6000]), tensor([0.])]},
#  {'diff': tensor([-46.6000]),
#   'episode_index': 386,
#   'timestamps': [tensor([46.6000]), tensor([0.])]},
#  {'diff': tensor([-30.]),
#   'episode_index': 387,
#   'timestamps': [tensor([30.]), tensor([0.])]},
#  {'diff': tensor([-37.9000]),
#   'episode_index': 388,
#   'timestamps': [tensor([37.9000]), tensor([0.])]},
#  {'diff': tensor([-26.5000]),
#   'episode_index': 389,
#   'timestamps': [tensor([26.5000]), tensor([0.])]},
#  {'diff': tensor([-48.3000]),
#   'episode_index': 390,
#   'timestamps': [tensor([48.3000]), tensor([0.])]},
#  {'diff': tensor([-58.8000]),
#   'episode_index': 391,
#   'timestamps': [tensor([58.8000]), tensor([0.])]},
#  {'diff': tensor([-53.3000]),
#   'episode_index': 392,
#   'timestamps': [tensor([53.3000]), tensor([0.])]},
#  {'diff': tensor([-48.1000]),
#   'episode_index': 393,
#   'timestamps': [tensor([48.1000]), tensor([0.])]},
#  {'diff': tensor([-28.8000]),
#   'episode_index': 394,
#   'timestamps': [tensor([28.8000]), tensor([0.])]},
#  {'diff': tensor([-38.3000]),
#   'episode_index': 395,
#   'timestamps': [tensor([38.3000]), tensor([0.])]},
#  {'diff': tensor([-33.5000]),
#   'episode_index': 396,
#   'timestamps': [tensor([33.5000]), tensor([0.])]},
#  {'diff': tensor([-26.9000]),
#   'episode_index': 397,
#   'timestamps': [tensor([26.9000]), tensor([0.])]},
#  {'diff': tensor([-40.9000]),
#   'episode_index': 398,
#   'timestamps': [tensor([40.9000]), tensor([0.])]},
#  {'diff': tensor([-33.2000]),
#   'episode_index': 399,
#   'timestamps': [tensor([33.2000]), tensor([0.])]},
#  {'diff': tensor([-41.9000]),
#   'episode_index': 400,
#   'timestamps': [tensor([41.9000]), tensor([0.])]},
#  {'diff': tensor([-22.4000]),
#   'episode_index': 401,
#   'timestamps': [tensor([22.4000]), tensor([0.])]},
#  {'diff': tensor([-19.9000]),
#   'episode_index': 402,
#   'timestamps': [tensor([19.9000]), tensor([0.])]},
#  {'diff': tensor([-20.9000]),
#   'episode_index': 403,
#   'timestamps': [tensor([20.9000]), tensor([0.])]},
#  {'diff': tensor([-19.5000]),
#   'episode_index': 404,
#   'timestamps': [tensor([19.5000]), tensor([0.])]},
#  {'diff': tensor([-29.]),
#   'episode_index': 405,
#   'timestamps': [tensor([29.]), tensor([0.])]},
#  {'diff': tensor([-27.4000]),
#   'episode_index': 406,
#   'timestamps': [tensor([27.4000]), tensor([0.])]},
#  {'diff': tensor([-58.]),
#   'episode_index': 407,
#   'timestamps': [tensor([58.]), tensor([0.])]},
#  {'diff': tensor([-31.6000]),
#   'episode_index': 408,
#   'timestamps': [tensor([31.6000]), tensor([0.])]},
#  {'diff': tensor([-23.3000]),
#   'episode_index': 409,
#   'timestamps': [tensor([23.3000]), tensor([0.])]},
#  {'diff': tensor([-34.7000]),
#   'episode_index': 410,
#   'timestamps': [tensor([34.7000]), tensor([0.])]},
#  {'diff': tensor([-36.9000]),
#   'episode_index': 411,
#   'timestamps': [tensor([36.9000]), tensor([0.])]},
#  {'diff': tensor([-22.]),
#   'episode_index': 412,
#   'timestamps': [tensor([22.]), tensor([0.])]},
#  {'diff': tensor([-29.9000]),
#   'episode_index': 413,
#   'timestamps': [tensor([29.9000]), tensor([0.])]},
#  {'diff': tensor([-26.5000]),
#   'episode_index': 414,
#   'timestamps': [tensor([26.5000]), tensor([0.])]},
#  {'diff': tensor([-11.7000]),
#   'episode_index': 415,
#   'timestamps': [tensor([11.7000]), tensor([0.])]},
#  {'diff': tensor([-32.1000]),
#   'episode_index': 416,
#   'timestamps': [tensor([32.1000]), tensor([0.])]},
#  {'diff': tensor([-22.]),
#   'episode_index': 417,
#   'timestamps': [tensor([22.]), tensor([0.])]},
#  {'diff': tensor([-27.]),
#   'episode_index': 418,
#   'timestamps': [tensor([27.]), tensor([0.])]},
#  {'diff': tensor([-23.3000]),
#   'episode_index': 419,
#   'timestamps': [tensor([23.3000]), tensor([0.])]},
#  {'diff': tensor([-35.2000]),
#   'episode_index': 420,
#   'timestamps': [tensor([35.2000]), tensor([0.])]},
#  {'diff': tensor([-36.1000]),
#   'episode_index': 421,
#   'timestamps': [tensor([36.1000]), tensor([0.])]},
#  {'diff': tensor([-31.7000]),
#   'episode_index': 422,
#   'timestamps': [tensor([31.7000]), tensor([0.])]},
#  {'diff': tensor([-26.3000]),
#   'episode_index': 423,
#   'timestamps': [tensor([26.3000]), tensor([0.])]},
#  {'diff': tensor([-29.7000]),
#   'episode_index': 424,
#   'timestamps': [tensor([29.7000]), tensor([0.])]},
#  {'diff': tensor([-17.5000]),
#   'episode_index': 425,
#   'timestamps': [tensor([17.5000]), tensor([0.])]},
#  {'diff': tensor([-23.3000]),
#   'episode_index': 426,
#   'timestamps': [tensor([23.3000]), tensor([0.])]},
#  {'diff': tensor([-22.1000]),
#   'episode_index': 427,
#   'timestamps': [tensor([22.1000]), tensor([0.])]},
#  {'diff': tensor([-36.]),
#   'episode_index': 428,
#   'timestamps': [tensor([36.]), tensor([0.])]},
#  {'diff': tensor([-30.8000]),
#   'episode_index': 429,
#   'timestamps': [tensor([30.8000]), tensor([0.])]},
#  {'diff': tensor([-38.7000]),
#   'episode_index': 430,
#   'timestamps': [tensor([38.7000]), tensor([0.])]},
#  {'diff': tensor([-23.7000]),
#   'episode_index': 431,
#   'timestamps': [tensor([23.7000]), tensor([0.])]},
#  {'diff': tensor([-37.7000]),
#   'episode_index': 432,
#   'timestamps': [tensor([37.7000]), tensor([0.])]},
#  {'diff': tensor([-34.4000]),
#   'episode_index': 433,
#   'timestamps': [tensor([34.4000]), tensor([0.])]},
#  {'diff': tensor([-19.9000]),
#   'episode_index': 434,
#   'timestamps': [tensor([19.9000]), tensor([0.])]},
#  {'diff': tensor([-18.9000]),
#   'episode_index': 435,
#   'timestamps': [tensor([18.9000]), tensor([0.])]},
#  {'diff': tensor([-20.6000]),
#   'episode_index': 436,
#   'timestamps': [tensor([20.6000]), tensor([0.])]},
#  {'diff': tensor([-41.3000]),
# ...
#   'timestamps': [tensor([31.2000]), tensor([0.])]},
#  {'diff': tensor([-28.7000]),
#   'episode_index': 1495,
#   'timestamps': [tensor([28.7000]), tensor([0.])]},
#  {'diff': tensor([-37.6000]),
#   'episode_index': 1496,
#   'timestamps': [tensor([37.6000]), tensor([0.])]},
#  {'diff': tensor([-6.]),
#   'episode_index': 1497,
#   'timestamps': [tensor([6.]), tensor([0.])]},
#  {'diff': tensor([-33.3000]),
#   'episode_index': 1498,
#   'timestamps': [tensor([33.3000]), tensor([0.])]},
#  {'diff': tensor([-21.2000]),
#   'episode_index': 1499,
#   'timestamps': [tensor([21.2000]), tensor([0.])]},
#  {'diff': tensor([-22.9000]),
#   'episode_index': 1500,
#   'timestamps': [tensor([22.9000]), tensor([0.])]},
#  {'diff': tensor([-25.3000]),
#   'episode_index': 1501,
#   'timestamps': [tensor([25.3000]), tensor([0.])]},
#  {'diff': tensor([-20.3000]),
#   'episode_index': 1502,
#   'timestamps': [tensor([20.3000]), tensor([0.])]},
#  {'diff': tensor([-18.]),
#   'episode_index': 1503,
#   'timestamps': [tensor([18.]), tensor([0.])]},
#  {'diff': tensor([-26.2000]),
#   'episode_index': 1504,
#   'timestamps': [tensor([26.2000]), tensor([0.])]},
#  {'diff': tensor([-36.6000]),
#   'episode_index': 1505,
#   'timestamps': [tensor([36.6000]), tensor([0.])]},
#  {'diff': tensor([-69.3000]),
#   'episode_index': 1506,
#   'timestamps': [tensor([69.3000]), tensor([0.])]},
#  {'diff': tensor([-60.]),
#   'episode_index': 1507,
#   'timestamps': [tensor([60.]), tensor([0.])]},
#  {'diff': tensor([-26.4000]),
#   'episode_index': 1508,
#   'timestamps': [tensor([26.4000]), tensor([0.])]},
#  {'diff': tensor([-53.2000]),
#   'episode_index': 1509,
#   'timestamps': [tensor([53.2000]), tensor([0.])]},
#  {'diff': tensor([-46.5000]),
#   'episode_index': 1510,
#   'timestamps': [tensor([46.5000]), tensor([0.])]},
#  {'diff': tensor([-37.2000]),
#   'episode_index': 1511,
#   'timestamps': [tensor([37.2000]), tensor([0.])]},
#  {'diff': tensor([-38.7000]),
#   'episode_index': 1512,
#   'timestamps': [tensor([38.7000]), tensor([0.])]},
#  {'diff': tensor([-30.7000]),
#   'episode_index': 1513,
#   'timestamps': [tensor([30.7000]), tensor([0.])]},
#  {'diff': tensor([-34.1000]),
#   'episode_index': 1514,
#   'timestamps': [tensor([34.1000]), tensor([0.])]},
#  {'diff': tensor([-57.]),
#   'episode_index': 1515,
#   'timestamps': [tensor([57.]), tensor([0.])]},
#  {'diff': tensor([-30.1000]),
#   'episode_index': 1516,
#   'timestamps': [tensor([30.1000]), tensor([0.])]},
#  {'diff': tensor([-33.1000]),
#   'episode_index': 1517,
#   'timestamps': [tensor([33.1000]), tensor([0.])]},
#  {'diff': tensor([-28.]),
#   'episode_index': 1518,
#   'timestamps': [tensor([28.]), tensor([0.])]},
#  {'diff': tensor([-47.3000]),
#   'episode_index': 1519,
#   'timestamps': [tensor([47.3000]), tensor([0.])]},
#  {'diff': tensor([-20.8000]),
#   'episode_index': 1520,
#   'timestamps': [tensor([20.8000]), tensor([0.])]},
#  {'diff': tensor([-31.3000]),
#   'episode_index': 1521,
#   'timestamps': [tensor([31.3000]), tensor([0.])]},
#  {'diff': tensor([-27.6000]),
#   'episode_index': 1522,
#   'timestamps': [tensor([27.6000]), tensor([0.])]},
#  {'diff': tensor([-43.8000]),
#   'episode_index': 1523,
#   'timestamps': [tensor([43.8000]), tensor([0.])]},
#  {'diff': tensor([-31.4000]),
#   'episode_index': 1524,
#   'timestamps': [tensor([31.4000]), tensor([0.])]},
#  {'diff': tensor([-25.1000]),
#   'episode_index': 1525,
#   'timestamps': [tensor([25.1000]), tensor([0.])]},
#  {'diff': tensor([-37.5000]),
#   'episode_index': 1526,
#   'timestamps': [tensor([37.5000]), tensor([0.])]},
#  {'diff': tensor([-28.6000]),
#   'episode_index': 1527,
#   'timestamps': [tensor([28.6000]), tensor([0.])]},
#  {'diff': tensor([-50.1000]),
#   'episode_index': 1528,
#   'timestamps': [tensor([50.1000]), tensor([0.])]},
#  {'diff': tensor([-38.2000]),
#   'episode_index': 1529,
#   'timestamps': [tensor([38.2000]), tensor([0.])]},
#  {'diff': tensor([-40.2000]),
#   'episode_index': 1530,
#   'timestamps': [tensor([40.2000]), tensor([0.])]},
#  {'diff': tensor([-36.]),
#   'episode_index': 1531,
#   'timestamps': [tensor([36.]), tensor([0.])]},
#  {'diff': tensor([-33.4000]),
#   'episode_index': 1532,
#   'timestamps': [tensor([33.4000]), tensor([0.])]},
#  {'diff': tensor([-37.]),
#   'episode_index': 1533,
#   'timestamps': [tensor([37.]), tensor([0.])]},
#  {'diff': tensor([-38.3000]),
#   'episode_index': 1534,
#   'timestamps': [tensor([38.3000]), tensor([0.])]},
#  {'diff': tensor([-33.4000]),
#   'episode_index': 1535,
#   'timestamps': [tensor([33.4000]), tensor([0.])]},
#  {'diff': tensor([-28.6000]),
#   'episode_index': 1536,
#   'timestamps': [tensor([28.6000]), tensor([0.])]},
#  {'diff': tensor([-55.5000]),
#   'episode_index': 1537,
#   'timestamps': [tensor([55.5000]), tensor([0.])]},
#  {'diff': tensor([-35.3000]),
#   'episode_index': 1538,
#   'timestamps': [tensor([35.3000]), tensor([0.])]},
#  {'diff': tensor([-28.7000]),
#   'episode_index': 1539,
#   'timestamps': [tensor([28.7000]), tensor([0.])]},
#  {'diff': tensor([-27.1000]),
#   'episode_index': 1540,
#   'timestamps': [tensor([27.1000]), tensor([0.])]},
#  {'diff': tensor([-51.6000]),
#   'episode_index': 1541,
#   'timestamps': [tensor([51.6000]), tensor([0.])]},
#  {'diff': tensor([-32.2000]),
#   'episode_index': 1542,
#   'timestamps': [tensor([32.2000]), tensor([0.])]},
#  {'diff': tensor([-33.6000]),
#   'episode_index': 1543,
#   'timestamps': [tensor([33.6000]), tensor([0.])]},
#  {'diff': tensor([-21.1000]),
#   'episode_index': 1544,
#   'timestamps': [tensor([21.1000]), tensor([0.])]},
#  {'diff': tensor([-57.8000]),
#   'episode_index': 1545,
#   'timestamps': [tensor([57.8000]), tensor([0.])]},
#  {'diff': tensor([-37.]),
#   'episode_index': 1546,
#   'timestamps': [tensor([37.]), tensor([0.])]},
#  {'diff': tensor([-46.6000]),
#   'episode_index': 1547,
#   'timestamps': [tensor([46.6000]), tensor([0.])]},
#  {'diff': tensor([-39.5000]),
#   'episode_index': 1548,
#   'timestamps': [tensor([39.5000]), tensor([0.])]},
#  {'diff': tensor([-41.5000]),
#   'episode_index': 1549,
#   'timestamps': [tensor([41.5000]), tensor([0.])]},
#  {'diff': tensor([-27.8000]),
#   'episode_index': 1550,
#   'timestamps': [tensor([27.8000]), tensor([0.])]},
#  {'diff': tensor([-29.]),
#   'episode_index': 1551,
#   'timestamps': [tensor([29.]), tensor([0.])]},
#  {'diff': tensor([-36.6000]),
#   'episode_index': 1552,
#   'timestamps': [tensor([36.6000]), tensor([0.])]},
#  {'diff': tensor([-40.5000]),
#   'episode_index': 1553,
#   'timestamps': [tensor([40.5000]), tensor([0.])]},
#  {'diff': tensor([-44.8000]),
#   'episode_index': 1554,
#   'timestamps': [tensor([44.8000]), tensor([0.])]},
#  {'diff': tensor([-31.7000]),
#   'episode_index': 1555,
#   'timestamps': [tensor([31.7000]), tensor([0.])]},
#  {'diff': tensor([-24.6000]),
#   'episode_index': 1556,
#   'timestamps': [tensor([24.6000]), tensor([0.])]},
#  {'diff': tensor([-23.5000]),
#   'episode_index': 1557,
#   'timestamps': [tensor([23.5000]), tensor([0.])]},
#  {'diff': tensor([-30.4000]),
#   'episode_index': 1558,
#   'timestamps': [tensor([30.4000]), tensor([0.])]},
#  {'diff': tensor([-33.2000]),
#   'episode_index': 1559,
#   'timestamps': [tensor([33.2000]), tensor([0.])]},
#  {'diff': tensor([-41.8000]),
#   'episode_index': 1560,
#   'timestamps': [tensor([41.8000]), tensor([0.])]},
#  {'diff': tensor([-56.6000]),
#   'episode_index': 1561,
#   'timestamps': [tensor([56.6000]), tensor([0.])]},
#  {'diff': tensor([-19.7000]),
#   'episode_index': 1562,
#   'timestamps': [tensor([19.7000]), tensor([0.])]},
#  {'diff': tensor([-29.6000]),
#   'episode_index': 1563,
#   'timestamps': [tensor([29.6000]), tensor([0.])]},
#  {'diff': tensor([-29.2000]),
#   'episode_index': 1564,
#   'timestamps': [tensor([29.2000]), tensor([0.])]},
#  {'diff': tensor([-34.5000]),
#   'episode_index': 1565,
#   'timestamps': [tensor([34.5000]), tensor([0.])]},
#  {'diff': tensor([-23.6000]),
#   'episode_index': 1566,
#   'timestamps': [tensor([23.6000]), tensor([0.])]},
#  {'diff': tensor([-36.3000]),
#   'episode_index': 1567,
#   'timestamps': [tensor([36.3000]), tensor([0.])]},
#  {'diff': tensor([-25.]),
#   'episode_index': 1568,
#   'timestamps': [tensor([25.]), tensor([0.])]},
#  {'diff': tensor([-34.6000]),
#   'episode_index': 1569,
#   'timestamps': [tensor([34.6000]), tensor([0.])]},
#  {'diff': tensor([-42.5000]),
#   'episode_index': 1570,
#   'timestamps': [tensor([42.5000]), tensor([0.])]},
#  {'diff': tensor([-22.1000]),
#   'episode_index': 1571,
#   'timestamps': [tensor([22.1000]), tensor([0.])]},
#  {'diff': tensor([-34.2000]),
#   'episode_index': 1572,
#   'timestamps': [tensor([34.2000]), tensor([0.])]},
#  {'diff': tensor([-24.8000]),
#   'episode_index': 1573,
#   'timestamps': [tensor([24.8000]), tensor([0.])]},
#  {'diff': tensor([-28.1000]),
#   'episode_index': 1574,
#   'timestamps': [tensor([28.1000]), tensor([0.])]},
#  {'diff': tensor([-31.1000]),
#   'episode_index': 1575,
#   'timestamps': [tensor([31.1000]), tensor([0.])]},
#  {'diff': tensor([-28.3000]),
#   'episode_index': 1576,
#   'timestamps': [tensor([28.3000]), tensor([0.])]},
#  {'diff': tensor([-39.1000]),
#   'episode_index': 1577,
#   'timestamps': [tensor([39.1000]), tensor([0.])]},
#  {'diff': tensor([-31.6000]),
#   'episode_index': 1578,
#   'timestamps': [tensor([31.6000]), tensor([0.])]},
#  {'diff': tensor([-23.2000]),
#   'episode_index': 1579,
#   'timestamps': [tensor([23.2000]), tensor([0.])]},
#  {'diff': tensor([-23.2000]),
#   'episode_index': 1580,
#   'timestamps': [tensor([23.2000]), tensor([0.])]},
#  {'diff': tensor([-31.1000]),
#   'episode_index': 1581,
#   'timestamps': [tensor([31.1000]), tensor([0.])]},
#  {'diff': tensor([-25.5000]),
#   'episode_index': 1582,
#   'timestamps': [tensor([25.5000]), tensor([0.])]},
#  {'diff': tensor([-36.2000]),
#   'episode_index': 1583,
#   'timestamps': [tensor([36.2000]), tensor([0.])]},
#  {'diff': tensor([-32.5000]),
#   'episode_index': 1584,
#   'timestamps': [tensor([32.5000]), tensor([0.])]},
#  {'diff': tensor([-21.5000]),
#   'episode_index': 1585,
#   'timestamps': [tensor([21.5000]), tensor([0.])]},
#  {'diff': tensor([-26.5000]),
#   'episode_index': 1586,
#   'timestamps': [tensor([26.5000]), tensor([0.])]},
#  {'diff': tensor([-52.3000]),
#   'episode_index': 1587,
#   'timestamps': [tensor([52.3000]), tensor([0.])]},
#  {'diff': tensor([-30.9000]),
#   'episode_index': 1588,
#   'timestamps': [tensor([30.9000]), tensor([0.])]},
#  {'diff': tensor([-27.8000]),
#   'episode_index': 1589,
#   'timestamps': [tensor([27.8000]), tensor([0.])]},
#  {'diff': tensor([-71.5000]),
#   'episode_index': 1590,
#   'timestamps': [tensor([71.5000]), tensor([0.])]},
#  {'diff': tensor([-28.8000]),
#   'episode_index': 1591,
#   'timestamps': [tensor([28.8000]), tensor([0.])]},
#  {'diff': tensor([-49.1000]),
#   'episode_index': 1592,
#   'timestamps': [tensor([49.1000]), tensor([0.])]},
#  {'diff': tensor([-46.7000]),
#   'episode_index': 1593,
#   'timestamps': [tensor([46.7000]), tensor([0.])]},
#  {'diff': tensor([-46.8000]),
#   'episode_index': 1594,
#   'timestamps': [tensor([46.8000]), tensor([0.])]},
#  {'diff': tensor([-33.1000]),
#   'episode_index': 1595,
#   'timestamps': [tensor([33.1000]), tensor([0.])]},
#  {'diff': tensor([-59.2000]),
#   'episode_index': 1596,
#   'timestamps': [tensor([59.2000]), tensor([0.])]},
#  {'diff': tensor([-52.4000]),
#   'episode_index': 1597,
#   'timestamps': [tensor([52.4000]), tensor([0.])]},
#  {'diff': tensor([-65.1000]),
#   'episode_index': 1598,
#   'timestamps': [tensor([65.1000]), tensor([0.])]},
#  {'diff': tensor([-37.7000]),
#   'episode_index': 1599,
#   'timestamps': [tensor([37.7000]), tensor([0.])]},
#  {'diff': tensor([-31.4000]),
#   'episode_index': 1600,
#   'timestamps': [tensor([31.4000]), tensor([0.])]},
#  {'diff': tensor([-77.]),
#   'episode_index': 1601,
#   'timestamps': [tensor([77.]), tensor([0.])]},
#  {'diff': tensor([-54.3000]),
#   'episode_index': 1602,
#   'timestamps': [tensor([54.3000]), tensor([0.])]},
#  {'diff': tensor([-22.1000]),
#   'episode_index': 1603,
#   'timestamps': [tensor([22.1000]), tensor([0.])]},
#  {'diff': tensor([-36.1000]),
#   'episode_index': 1604,
#   'timestamps': [tensor([36.1000]), tensor([0.])]},
#  {'diff': tensor([-31.6000]),
#   'episode_index': 1605,
#   'timestamps': [tensor([31.6000]), tensor([0.])]},
#  {'diff': tensor([-29.7000]),
#   'episode_index': 1606,
#   'timestamps': [tensor([29.7000]), tensor([0.])]},
#  {'diff': tensor([-28.7000]),
#   'episode_index': 1607,
#   'timestamps': [tensor([28.7000]), tensor([0.])]},
#  {'diff': tensor([-25.3000]),
#   'episode_index': 1608,
#   'timestamps': [tensor([25.3000]), tensor([0.])]},
#  {'diff': tensor([-28.7000]),
#   'episode_index': 1609,
#   'timestamps': [tensor([28.7000]), tensor([0.])]},
#  {'diff': tensor([-32.8000]),
#   'episode_index': 1610,
#   'timestamps': [tensor([32.8000]), tensor([0.])]},
#  {'diff': tensor([-53.6000]),
#   'episode_index': 1611,
#   'timestamps': [tensor([53.6000]), tensor([0.])]},
#  {'diff': tensor([-46.5000]),
#   'episode_index': 1612,
#   'timestamps': [tensor([46.5000]), tensor([0.])]},
#  {'diff': tensor([-16.8000]),
#   'episode_index': 1613,
#   'timestamps': [tensor([16.8000]), tensor([0.])]},
#  {'diff': tensor([-52.8000]),
#   'episode_index': 1614,
#   'timestamps': [tensor([52.8000]), tensor([0.])]},
#  {'diff': tensor([-33.8000]),
#   'episode_index': 1615,
#   'timestamps': [tensor([33.8000]), tensor([0.])]},
#  {'diff': tensor([-40.5000]),
#   'episode_index': 1616,
#   'timestamps': [tensor([40.5000]), tensor([0.])]},
#  {'diff': tensor([-28.9000]),
#   'episode_index': 1617,
#   'timestamps': [tensor([28.9000]), tensor([0.])]},
#  {'diff': tensor([-38.2000]),
#   'episode_index': 1618,
#   'timestamps': [tensor([38.2000]), tensor([0.])]},
#  {'diff': tensor([-39.4000]),
#   'episode_index': 1619,
#   'timestamps': [tensor([39.4000]), tensor([0.])]},
#  {'diff': tensor([-58.7000]),
#   'episode_index': 1620,
#   'timestamps': [tensor([58.7000]), tensor([0.])]},
#  {'diff': tensor([-36.6000]),
#   'episode_index': 1621,
#   'timestamps': [tensor([36.6000]), tensor([0.])]},
#  {'diff': tensor([-31.1000]),
#   'episode_index': 1622,
#   'timestamps': [tensor([31.1000]), tensor([0.])]},
#  {'diff': tensor([-74.7000]),
#   'episode_index': 1623,
#   'timestamps': [tensor([74.7000]), tensor([0.])]},
#  {'diff': tensor([-56.8000]),
#   'episode_index': 1624,
#   'timestamps': [tensor([56.8000]), tensor([0.])]},
#  {'diff': tensor([-37.1000]),
#   'episode_index': 1625,
#   'timestamps': [tensor([37.1000]), tensor([0.])]},
#  {'diff': tensor([-20.9000]),
#   'episode_index': 1626,
#   'timestamps': [tensor([20.9000]), tensor([0.])]},
#  {'diff': tensor([-28.2000]),
#   'episode_index': 1627,
#   'timestamps': [tensor([28.2000]), tensor([0.])]},
#  {'diff': tensor([-51.6000]),
#   'episode_index': 1628,
#   'timestamps': [tensor([51.6000]), tensor([0.])]},
#  {'diff': tensor([-43.5000]),
#   'episode_index': 1629,
#   'timestamps': [tensor([43.5000]), tensor([0.])]},
#  {'diff': tensor([-53.1000]),
#   'episode_index': 1630,
#   'timestamps': [tensor([53.1000]), tensor([0.])]},
#  {'diff': tensor([-44.]),
#   'episode_index': 1631,
#   'timestamps': [tensor([44.]), tensor([0.])]},
#  {'diff': tensor([-35.6000]),
#   'episode_index': 1632,
#   'timestamps': [tensor([35.6000]), tensor([0.])]},
#  {'diff': tensor([-69.1000]),
#   'episode_index': 1633,
#   'timestamps': [tensor([69.1000]), tensor([0.])]},
#  {'diff': tensor([-55.5000]),
#   'episode_index': 1634,
#   'timestamps': [tensor([55.5000]), tensor([0.])]},
#  {'diff': tensor([-22.5000]),
#   'episode_index': 1635,
#   'timestamps': [tensor([22.5000]), tensor([0.])]},
#  {'diff': tensor([-51.]),
#   'episode_index': 1636,
#   'timestamps': [tensor([51.]), tensor([0.])]},
#  {'diff': tensor([-76.6000]),
#   'episode_index': 1637,
#   'timestamps': [tensor([76.6000]), tensor([0.])]},
#  {'diff': tensor([-40.1000]),
#   'episode_index': 1638,
#   'timestamps': [tensor([40.1000]), tensor([0.])]},
#  {'diff': tensor([-31.5000]),
#   'episode_index': 1639,
#   'timestamps': [tensor([31.5000]), tensor([0.])]},
#  {'diff': tensor([-31.3000]),
#   'episode_index': 1640,
#   'timestamps': [tensor([31.3000]), tensor([0.])]},
#  {'diff': tensor([-44.8000]),
#   'episode_index': 1641,
#   'timestamps': [tensor([44.8000]), tensor([0.])]},
#  {'diff': tensor([-30.2000]),
#   'episode_index': 1642,
#   'timestamps': [tensor([30.2000]), tensor([0.])]},
#  {'diff': tensor([-40.6000]),
#   'episode_index': 1643,
#   'timestamps': [tensor([40.6000]), tensor([0.])]},
#  {'diff': tensor([-36.7000]),
#   'episode_index': 1644,
#   'timestamps': [tensor([36.7000]), tensor([0.])]}]

# %%
sec = len(dataset)
print(sec/36000)
# Out:
# 14.546555555555555
