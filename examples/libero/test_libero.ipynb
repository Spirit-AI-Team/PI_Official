# %%
import os
import cv2
import numpy as np
from lerobot.common.datasets.lerobot_dataset import LEROBOT_HOME
from lerobot.common.datasets.lerobot_dataset import LeRobotDataset
import ffmpeg

# %%
dataset = LeRobotDataset(repo_id='', local_files_only=True)
# Out:
# Returning existing local_dir `/pfstem/likaiyu/resources/lerobot/eefmvp` as remote repo cannot be accessed in `snapshot_download` (None).
# Returning existing local_dir `/pfstem/likaiyu/resources/lerobot/eefmvp` as remote repo cannot be accessed in `snapshot_download` (None).
# Resolving data files:   0%|          | 0/568 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0/568 [00:00<?, ?files/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Loading dataset shards:   0%|          | 0/54 [00:00<?, ?it/s]

# %%
dataset.fps
# Out:
# 30
