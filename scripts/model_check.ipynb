# %%
import openpi.models.model as _model
from openpi.models.pi0 import Pi0Config
import openpi.shared.download as download

# %%
cfg = Pi0Config()
ckpt_path = '/pfstem/likaiyu/resources/checkpoints/spi0_aloha_finetune_full/shirtflatten_0225_27_bases2_full/29999/params'
checkpoint_dir = download.maybe_download(ckpt_path)
model = cfg.load(_model.restore_params(checkpoint_dir))

# %%
import openpi.shared.nnx_utils as nnx_utils
nnx_utils.PathRegex(".*lora.*")(model)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 import openpi.shared.nnx_utils as nnx_utils
# ----> 2 nnx_utils.PathRegex(".*lora.*")(model)
#
# TypeError: PathRegex.__call__() missing 1 required positional argument: 'x'
